# %% [markdown]
# # 1.代价函数直观
# ![image.png](attachment:image.png)
# <font size=5>为了更好的解释代价函数，现在简化代价函数，只取一个未知参数θ</font>

# %% [markdown]
# # 2.0假设函数h(x)与代价函数j(θ)对比
# <font size=5>为了更好的解释代价函数，现在简化代价函数，只取一个未知参数θ
# <center>注明（假设函数h(x）</center>
#     <br>X：这里的横坐标表示房子的大小
#     <br>Y：纵坐标表示房价
#     <br>θ:令θ为1
#      <br>
#      <br>因此如左图的的假设函数中，我们有了数据集和参数值，那么我们就可以把代价函数j(θ）求出来
#       有因为假设函数h(x)与数据集完全拟合，h(x[i]）=y[i]可以得出j(θ)=j(1)=0
#     <br>
#     <center>注明（代价函数j(θ))</center>
#     <br>θ：因为代价函数j(θ)是关于θ的函数所以横坐标为θ
#     <br>j(θ)：因为当θ=1时代价函数h(x)与y完全重合，所以θ=1时j(θ)=0</font>
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <font size=5><center>那么当θ=0.5时又会变成什么样呢</center>
# </font>
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <font size=5><center>那么当θ=0时又会变成什么样呢</center>
#
#
# ![image.png](attachment:image.png)
#
# <br>如果θ=负数又会怎么样呢，这样算出来的代价函数j(θ)就会得到一个较大的误差。
# <br>因此我们可以看出参数值选取的不同代价函数j(θ)的误差就会不同。
# </font>

# %% [markdown]
# # 3.0为什么代价函数j(θ)取最小值，就可以得到一条最拟合的线呢？
# <font size=5><br>1.0那么如果θ取遍所有值，就会得到这样一条曲线，这就是j(θ)
#          <br>2.0对于任意的一个θ值都对应着左边图中的一条假设函数h(x)
#          <br>3.0还记得我们的目地吗，我们要找到就是j(θ)的最小值，而θ=1时正好是最小值，看左图也正好是最拟合的线
#
# ![image.png](attachment:image.png)
# </font>
