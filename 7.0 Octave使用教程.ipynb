# %% [markdown]
# <font size=5>
#     <br>1.0 pwd可以显示出octave的路径
#     <br>2.0读取da数据集，只需要cd到目录里。然后使用 load 文件名即可，然后可用who来查看存在哪个变量里，当然使用whos能更加详细
#     <br>3.0使用clear 来删除变量
# </font>
#
#
# ![title](47.png)
#
#
# ![title](48.png)
#
#
# <font size=5>
#    <br>4.0存储数据V=priceY（1：10）存储priceY矩阵的，前十条数据，存储到磁盘里如下
# </font>
#
# ![title](49.png)
#
#
# <font size=5>
#    <br>5.0如果想存成一个人能看得到的文件可以如下
# </font>
#
# ![title](50.png)
#
# <font size=5>
#    <br>6.0快速设置矩阵的倍数，如果我写的是A.^2就表示每个数字的平方，我也可以使用1 ./ A
# </font>
#
# ![title](51.png)
#
# ![title](52.png)
#
# <font size=5>
#    <br>7.0A的转置，A'
# </font>
#
# ![title](53.png)
#
# <font size=5>
#    <br>8.0这里有个有趣的放magic，输出的矩阵，每一行一列，对角相加都得到一样的数
# </font>
#
# ![title](54.png)
#
# <font size=5>
#    <br>9.0 叠加方法 sum(a)，prod(a)方法则是相乘，floor(A)则是把矩阵里的数向下四舍五入，如0.5就会变为0，ceil(A)就是向上四舍五入
# </font>
#
# ![title](55.png)
#
# <font size=5>
#    <br>10.0反对角矩阵flipud(eye(9))
# </font>
#
# ![title](56.png)
#
# <font size=5>
#    <br>11.0逆矩阵 pinv,这个操作是伪逆矩阵，不管有没有逆矩阵，都可求得。如下的逆矩阵乘以矩阵得到的就是一个identity matrix。
# </font>
#
# ![title](57.png)
