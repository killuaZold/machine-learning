# %% [markdown]
# <font size=5>1.0 for循环的使用，可以看到功能语句使用的是，赋值语句用的是;。
#
# </font>
#
# ![title](67.png)
#
# <font size=5>你还可以设置一个indices，如下，同理break和continue也可以使用到其中
#
# </font>
#
# ![title](68.png)
#
#
# <font size=5>2.0while的使用
#
# </font>
#
# ![title](69.png)
#
#
# <font size=5>3.0 break if 的使用
#
# </font>
#
# ![title](70.png)
#
#
# <font size=5>4.0 if else  elseif的使用
#
# </font>
#
# ![title](71.png)
#
#
# <font size=5>5.0函数，首先要在桌面建立一个.m文件，然后要进入到函数的路劲才能调用，octave的函数还可以返回两个参数
#
# </font>
#
# ![title](72.png)
#
# ![title](73.png)
#
# ![title](74.png)
#
# ![title](75.png)
#
#
# <font size=5>6.0来个复杂的例子如下，计算j(θ)函数，假设有如下数据集，根据如下的数据集构造出设计矩阵X，前面的1是因为构造出来的假设h=θ0+θ1x。以及结果矩阵y。然后我们把θ0设置为0，θ1设置为1，这样就符合下图了
# </font>
#
# ![title](76.png)
#
# ![title](77.png)
#
# <font size=5><br>以下这个函数是用来算j（θ）的j,函数的定义如下
# </font>
#
# ![title](78.png)
#
# ![title](79.png)
#
#
# <font size=5><br>输入θ向量，X，Y就可以得出代价函数的值，结果为0，是因为当前的参数值θ使用的h函数完全契合点
#
# </font>
#
# ![title](80.png)
