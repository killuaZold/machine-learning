# %% [markdown]
# # 例如：假设一个关于房子的面积与价格的数据集画出来如下
# ![image.png](attachment:image.png)
# #纵坐标表示每一平方英尺的价格，
# #横坐标表示不同房子的面积

# %% [markdown]
# 假设你的一个朋友拥有一座750平方英尺的房子，并且你的这位朋友想卖掉它，那么应该如何通过机器学习的方法来帮助你定价呢？
# 学习算法想通过画一条直线去拟合这些离散点，从而找到房子大小与价格的线性关系，因此750英尺的房子在图上可能可以卖出这个价格
# ![image.png](attachment:image.png)

# %% [markdown]
# 但这也许并不是最好的学习算法，也许二次函数或者二次多项式能够更好的拟合这些点，如果选择了二次函数这栋750英尺的房子，似乎卖20w更合适
# 那么如何决策使用直线拟合还是二次函数拟合呢，稍后说
# ![image.png](attachment:image.png)
#
# 以上就是一个有监督学习的算法：
#     ##在这个算法里，数据集也可以叫做答案集，我们把房子的实际大小所对应的销售价格告诉算法。而这个算法的任务就是生成更多的这些答案对。
#     ##即正确的房子大小 对应 正确的价格。这样的问题 也被称为回归问题。
#
# 回归问题：
#     ##我们试图去预测一个连续出输出值，即房子的价格，我们认为房价是一个实数，一个标量，作为一个连续的数值。
#     ##术语回归：指的是将要预测出连续值属性的类型

# %% [markdown]
# # 例子2：发现肿瘤后预测肿瘤是恶性肿瘤还是良性肿瘤
#
#
# ![image.png](attachment:image.png)
# #横坐标：肿瘤大小
# #纵坐标：哪个是恶性肿瘤，哪个是良性肿瘤

# %% [markdown]
# 假设一个人有一个肿瘤，大小为横坐标上的紫色点，那么这里学习算法的任务就是算出这个肿瘤是恶性肿瘤或者良性肿瘤的概率
# ![image.png](attachment:image.png)
#     #以上这个问题其实就是一个分类问题
#     #分类就是这样的一个事实，我们试图预测离散值输出0或1，恶性或良性
#     #在分类问题中有可能会输出两个以上的值，假设有一种肿瘤 除了恶性，良性还有中性，那么可用输出0，1，2

# %% [markdown]
# # 例子三：多属性预测，以上两个例子，不管是房子还是肿瘤的预测，我们的欧只用了一个属性来预测
#
# #纵坐标表示年龄
# #横坐标表示肿瘤大小
# #这样就构成了用两个属性来预测，该肿瘤是恶性肿瘤还是良性肿瘤，图中x表示恶性，圆圈表示良性，紫色圈表示你的朋友得了肿瘤，而他的肿瘤大小，和年龄都在图上
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 那么学习算法的任务，在这里就是画出一条线来把恶性肿瘤和良性肿瘤分开。这里学习算法告诉你，你朋友的肿瘤更有可能是良性的
# ![image.png](attachment:image.png)

# %% [markdown]
# # 支持向量机
#
# #有时候我们希望处理并不仅仅是量到三个特征。例如肿瘤是良性或者是恶性，并不能仅仅只依靠年龄和肿瘤大小进行判断。而是需要更多的特征来进行判断
#
# #那么如果我们有无限的特征可以用来判断肿瘤的恶性良性应该怎么办呢？要知道计算机的内存可是有限的，怎么可以用来存储无限的东西呢
# #在谈到支持向量机时，会有一个很好的办法来解决

# %% [markdown]
# # 总结
#
# 在监督学习中，我们得到了一个数据集，并且已经知道我们正确的输出应该是什么样子，并认为输入和输出之间存在关系。
# 监督学习问题分为“回归”和“分类”问题。
#
# #在回归问题中，我们试图预测连续输出中的结果，这意味着我们试图将输入变量映射到某个连续函数。
# #在分类问题中，我们改为尝试预测离散输出中的结果。换句话说，我们正在尝试将输入变量映射为离散类别。
