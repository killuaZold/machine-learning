# %% [markdown]
# # 1.0代价函数
# <font size=5>我们将使用以下的函数，我们该如何选择θ参数从而得到不同的假设函数</font>
# ![image.png](attachment:image.png)
# <font size=5>下面来看看不同的θ对应的函数图像</font>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 2.0改如何选择θ？
# <font size=5><br>  1.0我们希望h(x)与y的值尽可能的接近，这就是我们选择θ的根据
#          <br>  2.0在图上也就是表示为h(x)与y的欧氏距离最短，那么就可表示为min(h(x)-y)的平方最小
#          <br>  3.0因此我们需要求的是样本中的所有(x[i],y[i])，对应min(h(x)-y)的和的最小值如下图所示
#          <br>
#          <br>  以上就表明了θ的选取是为了使h(x)-y最小，最后代价函数就定义为一个j(θ0，θ1）
#          <br>  前面的1/2是为了求导以后消2，只要求θ0，θ1是得j最小就可以了。
#          <br>  平方差代价函数 为什么我们要使用平方 结果表明，这些平方差代价函数是一个合理的选择 适用于大多数的回归程序和问题，1/M是为了减小误差</font>
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
